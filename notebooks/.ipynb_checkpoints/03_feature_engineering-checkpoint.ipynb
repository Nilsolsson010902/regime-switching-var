# %% [markdown]
# ## Feature Engineering for Regime Detection
#
# The objective of this notebook is to construct informative features that summarize different aspects of market behaviour. These features will serve as the observation vector for the Hidden Markov Model, enabling it to identify latent market regimes rather than relying solely on daily returns.
